# %% [markdown]
# # DAAAnalyzer_2.0.AnalyzeABRs.ipynb
# Created by: JFranco | Created On: 27 NOV 2024 | Last Env: QISHA | Last Run Date: 27 NOV 2024
#
# This Python notebook will read in all DPOAE files for a specific DAA Run as specified by the user. It will make a lineplot for all availble files and label them by category.

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import glob
import os
import xlrd
import math
import matplotlib.pyplot as plt

# %%
#                *** WHAT TO ANALYZE // WHERE TO GET/STORE **
# Key identifiers
prepID = 'CMI_003'
daaRun = '1'
daaType = 'Pre-Noise Exposure'
isoFile = 'IsoDP-'+daaRun+'-1.tsv'
fnMD = 'CMI_003.Metadata.AnimalInfo.csv'
fileFiltered = "ABR-1-1.tsv-filtered.txt"
fileAnalyzed = "ABR-1-1.tsv-analyzed.txt"

# Directories 
#   existing ones 
dirMain = '/Users/joyfranco/Dropbox (Partners HealthCare)/JF_Shared/Data/CFTS/'
dirPrep = dirMain+prepID+'/'
dirData = dirPrep+'RawData/'
dirMD = dirPrep+'Metadata/'
pathTest = dirData+prepID+".C016.1/"

#   ones that need to be made    
dirSV = dirPrep+'Results/'

# %%
df = pd.read_csv(pathTest+fileFiltered, delimiter='\t', header=0) 
df
# Out:
#      Time (ms)   20.0 dB   25.0 dB   30.0 dB   35.0 dB   40.0 dB   45.0 dB  \
# 0         0.00 -0.025547  0.008846 -0.073541 -0.057114  0.009052 -0.003221
# 1         0.04 -0.047892  0.013597 -0.110884 -0.017521  0.004125 -0.014425
# 2         0.08 -0.059329  0.024015 -0.141212  0.002861 -0.004226 -0.021701
# 3         0.12 -0.067238  0.051110 -0.161291  0.000600 -0.013252 -0.021316
# 4         0.16 -0.080206  0.086448 -0.174117 -0.028970 -0.017787 -0.017246
# ..         ...       ...       ...       ...       ...       ...       ...
# 208       8.32 -0.025066  0.052784  0.108355 -0.059496  0.007201 -0.019352
# 209       8.36 -0.025428  0.043189  0.108422 -0.041101  0.017096  0.002066
# 210       8.40 -0.016859  0.034102  0.085038 -0.031977  0.014460  0.011595
# 211       8.44 -0.006861  0.030745  0.062501 -0.033138  0.009868  0.002486
# 212       8.48 -0.010304  0.034020  0.057715 -0.041572  0.008891 -0.016235
#
#       50.0 dB   55.0 dB   60.0 dB
# ...

# %%
df = pd.read_csv(pathTest+fileAnalyzed, sep="\t", skiprows=6) 
df
# Out:
#    Level  0.3msec Avg  0.3msec StDev  P1 Latency  P1 Amplitude  N1 Latency  \
# 0   60.0    -0.019814       0.024346        1.76          0.50        2.32
# 1   55.0    -0.100166       0.027089        1.84          0.38        2.28
# 2   50.0    -0.137518       0.033659        1.96          0.35        2.36
# 3   45.0    -0.014788       0.005835        2.00          0.15        2.32
# 4   40.0    -0.012166       0.015355        2.20          0.15        2.52
# 5   35.0    -0.031259       0.025727       -2.20          0.16       -2.68
# 6   30.0    -0.146575       0.038171       -2.20          0.10       -2.56
# 7   25.0     0.061144       0.045714       -2.32          0.10       -2.56
# 8   20.0    -0.062474       0.019013       -2.60          0.19       -3.20
#
#    N1 Amplitude  P2 Latency  P2 Amplitude  N2 Latency  ...  P4 Latency  \
# 0         -0.22        2.56          0.14        2.68  ...        4.56
# 1         -0.11        2.68          0.25        3.12  ...        4.68
# ...

# %%
#    *** LOAD MD SHEETS **
# Sample metadata sheet that include animal and condition info
dfMD = pd.read_csv(dirMD+fnMD)
dfMD.reset_index(inplace=True)
dfMD
# Out:
#    index AnimalID Sex      DOB    CMIID InjectionDate  AgeAtInjection Package  \
# 0      0     C016   M  9/24/24  CMI_003      11/11/24               7     AAV
# 1      1     C017   F  9/24/24  CMI_003      11/11/24               7     AAV
# 2      2     C018   M  9/24/24  CMI_003      11/11/24               7     AAV
# 3      3     C019   F  9/24/24  CMI_003      11/11/24               7     AAV
# 4      4     C020   M  9/24/24  CMI_003      11/11/24               7     AAV
# 5      5     C021   F  9/24/24  CMI_003      11/11/24               7     AAV
# 6      6     C022   M  9/24/24  CMI_003      11/11/24               7     AAV
# 7      7     C023   F  9/24/24  CMI_003      11/11/24               7     AAV
#
#   InjGroup   NE    NEDate  AgeAtNE  NELevel NEBand NEDuration  NEGroup
# 0   HABclw  Yes  11/25/24        9     97.5   8_16         2h        1
# 1   HABclw  Yes  11/25/24        9     97.5   8_16         2h        2
# ...

# %%
#           *** INITIALIZE RUN SPECIFIC DIRECTORY ETC FOR STORING RESULTS **
# Create directory for storing spreadsheetS and summary plotS for this run
if not os.path.exists(dirSV): os.mkdir(dirSV)

# %%
#           *** GENERATE A LIST OF DAA FOLDERS THAT WILL BE ANALYZED **
# Get a list of all the folders that match the prep
allData = os.listdir(dirData)
dataList = []
for datum in allData:
    if ('.'+daaRun) in datum:
        dataList.append(datum)
dataList
# Out:
# ['CMI_003.C020.1',
#  'CMI_003.C023.1',
#  'CMI_003.C016.1',
#  'CMI_003.C018.1',
#  'CMI_003.C022.1',
#  'CMI_003.C017.1',
#  'CMI_003.C019.1',
#  'CMI_003.C021.1']

# %%
#           *** ITERATE THROUGH FOLDERS AND GENERATE ABR PLOTS **
# 1. Open the folder and get all available ABR files
for daa in dataList:
    # Setup the path to the file
    abrFold = dirData+daa+'/'
    # Get a list of available ABR files
    allFiles = os.listdir(abrFold)
    files = []
    for file in allFiles:
        if ("ABR-"+daaRun) in file:
            files.append(file)
    # Go through the files and make a line plot that contains all ABRs for that frequency
    for file in files:
        # Setup the path to the file
        path = dirData+daa+'/'+file
        # Read in the file & make adjustments for readability
        dfABR = pd.read_csv(path, sep='\t', encoding='unicode_escape', lineterminator='\n')
        # Have to get out:
        freq = dfABR.columns.tolist()[6][8:-1]
        # Levels
        # Number of averages -- for each column showing

# %%
str = dfABR.iloc[0].values[0][7:-1]

# %%
tries = [i.strip() for i in str.split(';')]
tries
# Out:
# ['554', '566', '558', '552', '250']

# %%
# This one is going to be harder because the levels are embedded and it'll be hard to say how the indexing changes.
# Should pln on just searching for the word LEVELS: and then get all of the characters until the next "\r"
dfABR.iloc[1].values[0]
# Out:
# array(['\r:CFTS Version: V2.37.2 (R3282)\r:LEVELS:20;25;30;35;40;\r:DATA\r -0.050935',
#        0.074373, -0.064534, 0.03543, -0.020103, nan, nan, nan, nan, nan,
#        nan, nan], dtype=object)
